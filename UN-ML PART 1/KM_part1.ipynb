# %%
# import the make_blobs for the unlabeled random dataset of unsupervise learning

import seaborn as sns
from sklearn.datasets import make_blobs

# %%
# defining the X and y according to the data
# center is a number of clusters

X,y=make_blobs(
    n_samples=1000,
    n_features=2,
    centers=4,
    random_state=42
)

# %%
# VISUALIZATION
" here the x exes we put the X 0th index features values and y exes we put the X 1th index feature"

sns.scatterplot(x=X[:, 0],y=X[:, 1])
# Out:
# <Axes: >

# %% [markdown]
# # K-Means Clustering

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ### Create The Model

# %%
# building the model and train it in thw whole datasets
# we dont have any outputs thats why we dont need to fit thw data into model its automatickly

K=4

Kmeans=KMeans(
    n_clusters=K,
    random_state=42
)

# %%
# fit and predict in both because we do not know any outputs

labels=Kmeans.fit_predict(X)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %% [markdown]
# # data visualizatioin using the sns and the labels vales

# %%
# put the labels value
sns.scatterplot(x=X[:, 0],y=X[:, 1],c=labels)
# Out:
# <Axes: >
